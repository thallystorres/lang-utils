# %% [markdown]
# # Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a lib

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.json()
# Out:
# [{'id': '48290683393',
#   'type': 'PushEvent',
#   'actor': {'id': 7234006,
#    'login': 'blms',
#    'display_login': 'blms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/blms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7234006?'},
#   'repo': {'id': 297446715,
#    'name': 'Princeton-CDH/geniza',
#    'url': 'https://api.github.com/repos/Princeton-CDH/geniza'},
#   'payload': {'repository_id': 297446715,
#    'push_id': 23549046795,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/1755-regex-expansion',
#    'head': '609f26a45648d9543c753a5063cd31c77432f07c',
#    'before': '74b60bf717653334383bfe1e057bc4de08871c39',
#    'commits': [{'sha': '609f26a45648d9543c753a5063cd31c77432f07c',
#      'author': {'email': 'ben@performantsoftware.com',
#       'name': 'Ben Silverman'},
#      'message': 'Add shelfmark regex search, deploy notes (#1755)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Princeton-CDH/geniza/commits/609f26a45648d9543c753a5063cd31c77432f07c'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 9663986,
#    'login': 'Princeton-CDH',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Princeton-CDH',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9663986?'}},
#  {'id': '48290683400',
#   'type': 'PublicEvent',
#   'actor': {'id': 61960212,
#    'login': 'Murphite',
#    'display_login': 'Murphite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Murphite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61960212?'},
#   'repo': {'id': 948984629,
#    'name': 'Murphite/BodyWorthy-main',
#    'url': 'https://api.github.com/repos/Murphite/BodyWorthy-main'},
#   'payload': {},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683429',
#   'type': 'CreateEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 69119365,
#    'name': 'python-social-auth/social-docs',
#    'url': 'https://api.github.com/repos/python-social-auth/social-docs'},
#   'payload': {'ref': 'renovate/astral-sh-ruff-pre-commit-0.x',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Python Social Auth - Docs',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 21279195,
#    'login': 'python-social-auth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/python-social-auth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21279195?'}},
#  {'id': '48290683369',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 167813155,
#    'login': 'plutointegtestuser',
#    'display_login': 'plutointegtestuser',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/plutointegtestuser',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167813155?'},
#   'repo': {'id': 790388997,
#    'name': 'plutointegtestuser/jsNPMPackage',
#    'url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5',
#     'repository_url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage',
#     'labels_url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5/events',
#     'html_url': 'https://github.com/plutointegtestuser/jsNPMPackage/issues/5',
#     'id': 2269551517,
#     'node_id': 'I_kwDOLxxhBc6HRpud',
#     'number': 5,
#     'title': 'New issue created by PlatoPCN',
#     'user': {'login': 'plutointegtestuser',
#      'id': 167813155,
#      'node_id': 'U_kgDOCgCgIw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/167813155?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/plutointegtestuser',
#      'html_url': 'https://github.com/plutointegtestuser',
#      'followers_url': 'https://api.github.com/users/plutointegtestuser/followers',
#      'following_url': 'https://api.github.com/users/plutointegtestuser/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/plutointegtestuser/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/plutointegtestuser/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/plutointegtestuser/subscriptions',
#      'organizations_url': 'https://api.github.com/users/plutointegtestuser/orgs',
#      'repos_url': 'https://api.github.com/users/plutointegtestuser/repos',
#      'events_url': 'https://api.github.com/users/plutointegtestuser/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/plutointegtestuser/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 27,
#     'created_at': '2024-04-29T17:17:34Z',
#     'updated_at': '2025-04-03T14:55:13Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/comments/2776069605',
#     'html_url': 'https://github.com/plutointegtestuser/jsNPMPackage/issues/5#issuecomment-2776069605',
#     'issue_url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/5',
#     'id': 2776069605,
#     'node_id': 'IC_kwDOLxxhBc6ld3Xl',
#     'user': {'login': 'plutointegtestuser',
#      'id': 167813155,
#      'node_id': 'U_kgDOCgCgIw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/167813155?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/plutointegtestuser',
#      'html_url': 'https://github.com/plutointegtestuser',
#      'followers_url': 'https://api.github.com/users/plutointegtestuser/followers',
#      'following_url': 'https://api.github.com/users/plutointegtestuser/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/plutointegtestuser/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/plutointegtestuser/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/plutointegtestuser/subscriptions',
#      'organizations_url': 'https://api.github.com/users/plutointegtestuser/orgs',
#      'repos_url': 'https://api.github.com/users/plutointegtestuser/repos',
#      'events_url': 'https://api.github.com/users/plutointegtestuser/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/plutointegtestuser/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-04-03T14:55:12Z',
#     'updated_at': '2025-04-03T14:55:12Z',
#     'author_association': 'OWNER',
#     'body': 'new comment on 1743692076141',
#     'reactions': {'url': 'https://api.github.com/repos/plutointegtestuser/jsNPMPackage/issues/comments/2776069605/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683390',
#   'type': 'PushEvent',
#   'actor': {'id': 204804773,
#    'login': 'karimadvertising',
#    'display_login': 'karimadvertising',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karimadvertising',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/204804773?'},
#   'repo': {'id': 954984106,
#    'name': 'karimadvertising/kazrimza',
#    'url': 'https://api.github.com/repos/karimadvertising/kazrimza'},
#   'payload': {'repository_id': 954984106,
#    'push_id': 23549046937,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bb9ea49d2a0b81a9b9a7c0cb0a9cbc96078708bf',
#    'before': '5fbd48e5152e6e787f352e9ac950bd865f94b306',
#    'commits': [{'sha': 'bb9ea49d2a0b81a9b9a7c0cb0a9cbc96078708bf',
#      'author': {'email': 'ltd.karimadvertising@gmail.com',
#       'name': 'karimadvertising'},
#      'message': 'Updated the data.txt file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/karimadvertising/kazrimza/commits/bb9ea49d2a0b81a9b9a7c0cb0a9cbc96078708bf'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683350',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 32094306,
#    'login': 'vzhovnitsky',
#    'display_login': 'vzhovnitsky',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vzhovnitsky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32094306?'},
#   'repo': {'id': 441976969,
#    'name': 'tonwhales/wallet',
#    'url': 'https://api.github.com/repos/tonwhales/wallet'},
#   'payload': {'action': 'closed',
#    'number': 1478,
#    'pull_request': {'url': 'https://api.github.com/repos/tonwhales/wallet/pulls/1478',
#     'id': 2437323713,
#     'node_id': 'PR_kwDOGlgIic6RRpvB',
#     'html_url': 'https://github.com/tonwhales/wallet/pull/1478',
#     'diff_url': 'https://github.com/tonwhales/wallet/pull/1478.diff',
#     'patch_url': 'https://github.com/tonwhales/wallet/pull/1478.patch',
#     'issue_url': 'https://api.github.com/repos/tonwhales/wallet/issues/1478',
#     'number': 1478,
#     'state': 'closed',
#     'locked': False,
#     'title': 'fix: rm logs',
#     'user': {'login': 'vzhovnitsky',
#      'id': 32094306,
#      'node_id': 'MDQ6VXNlcjMyMDk0MzA2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/32094306?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vzhovnitsky',
#      'html_url': 'https://github.com/vzhovnitsky',
#      'followers_url': 'https://api.github.com/users/vzhovnitsky/followers',
#      'following_url': 'https://api.github.com/users/vzhovnitsky/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vzhovnitsky/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vzhovnitsky/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vzhovnitsky/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vzhovnitsky/orgs',
#      'repos_url': 'https://api.github.com/users/vzhovnitsky/repos',
#      'events_url': 'https://api.github.com/users/vzhovnitsky/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vzhovnitsky/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2025-04-03T14:55:06Z',
#     'updated_at': '2025-04-03T14:55:12Z',
#     'closed_at': '2025-04-03T14:55:12Z',
#     'merged_at': '2025-04-03T14:55:12Z',
#     'merge_commit_sha': 'f970c8069318cd682df69a86a416c2116436398d',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tonwhales/wallet/pulls/1478/commits',
#     'review_comments_url': 'https://api.github.com/repos/tonwhales/wallet/pulls/1478/comments',
#     'review_comment_url': 'https://api.github.com/repos/tonwhales/wallet/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tonwhales/wallet/issues/1478/comments',
#     'statuses_url': 'https://api.github.com/repos/tonwhales/wallet/statuses/2b57370aadbaa880b86ad18228b5ebb1495a3c37',
#     'head': {'label': 'tonwhales:cleanup/rm-logs',
#      'ref': 'cleanup/rm-logs',
#      'sha': '2b57370aadbaa880b86ad18228b5ebb1495a3c37',
#      'user': {'login': 'tonwhales',
#       'id': 94789130,
#       'node_id': 'O_kgDOBaZeCg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/94789130?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tonwhales',
#       'html_url': 'https://github.com/tonwhales',
#       'followers_url': 'https://api.github.com/users/tonwhales/followers',
#       'following_url': 'https://api.github.com/users/tonwhales/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tonwhales/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tonwhales/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tonwhales/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tonwhales/orgs',
#       'repos_url': 'https://api.github.com/users/tonwhales/repos',
#       'events_url': 'https://api.github.com/users/tonwhales/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tonwhales/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 441976969,
#       'node_id': 'R_kgDOGlgIiQ',
#       'name': 'wallet',
#       'full_name': 'tonwhales/wallet',
#       'private': False,
#       'owner': {'login': 'tonwhales',
#        'id': 94789130,
#        'node_id': 'O_kgDOBaZeCg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/94789130?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tonwhales',
#        'html_url': 'https://github.com/tonwhales',
#        'followers_url': 'https://api.github.com/users/tonwhales/followers',
#        'following_url': 'https://api.github.com/users/tonwhales/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tonwhales/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tonwhales/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tonwhales/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tonwhales/orgs',
#        'repos_url': 'https://api.github.com/users/tonwhales/repos',
#        'events_url': 'https://api.github.com/users/tonwhales/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tonwhales/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/tonwhales/wallet',
#       'description': 'Fast, secure and modern wallet for TONCOIN',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tonwhales/wallet',
#       'forks_url': 'https://api.github.com/repos/tonwhales/wallet/forks',
#       'keys_url': 'https://api.github.com/repos/tonwhales/wallet/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tonwhales/wallet/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tonwhales/wallet/teams',
#       'hooks_url': 'https://api.github.com/repos/tonwhales/wallet/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tonwhales/wallet/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tonwhales/wallet/events',
#       'assignees_url': 'https://api.github.com/repos/tonwhales/wallet/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tonwhales/wallet/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tonwhales/wallet/tags',
#       'blobs_url': 'https://api.github.com/repos/tonwhales/wallet/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tonwhales/wallet/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tonwhales/wallet/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tonwhales/wallet/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tonwhales/wallet/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tonwhales/wallet/languages',
#       'stargazers_url': 'https://api.github.com/repos/tonwhales/wallet/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tonwhales/wallet/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tonwhales/wallet/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tonwhales/wallet/subscription',
#       'commits_url': 'https://api.github.com/repos/tonwhales/wallet/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tonwhales/wallet/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tonwhales/wallet/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tonwhales/wallet/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tonwhales/wallet/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tonwhales/wallet/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tonwhales/wallet/merges',
#       'archive_url': 'https://api.github.com/repos/tonwhales/wallet/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tonwhales/wallet/downloads',
#       'issues_url': 'https://api.github.com/repos/tonwhales/wallet/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tonwhales/wallet/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tonwhales/wallet/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tonwhales/wallet/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tonwhales/wallet/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tonwhales/wallet/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tonwhales/wallet/deployments',
#       'created_at': '2021-12-26T20:22:45Z',
#       'updated_at': '2025-04-03T10:01:00Z',
#       'pushed_at': '2025-04-03T14:55:12Z',
#       'git_url': 'git://github.com/tonwhales/wallet.git',
#       'ssh_url': 'git@github.com:tonwhales/wallet.git',
#       'clone_url': 'https://github.com/tonwhales/wallet.git',
#       'svn_url': 'https://github.com/tonwhales/wallet',
#       'homepage': '',
#       'size': 83588,
#       'stargazers_count': 160,
#       'watchers_count': 160,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 59,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 59,
#       'open_issues': 14,
#       'watchers': 160,
#       'default_branch': 'master'}},
#     'base': {'label': 'tonwhales:develop',
#      'ref': 'develop',
#      'sha': '47410f6976f011527b0329a94d4f1af31effcea4',
#      'user': {'login': 'tonwhales',
#       'id': 94789130,
#       'node_id': 'O_kgDOBaZeCg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/94789130?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tonwhales',
#       'html_url': 'https://github.com/tonwhales',
#       'followers_url': 'https://api.github.com/users/tonwhales/followers',
#       'following_url': 'https://api.github.com/users/tonwhales/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tonwhales/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tonwhales/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tonwhales/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tonwhales/orgs',
#       'repos_url': 'https://api.github.com/users/tonwhales/repos',
#       'events_url': 'https://api.github.com/users/tonwhales/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tonwhales/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 441976969,
#       'node_id': 'R_kgDOGlgIiQ',
#       'name': 'wallet',
#       'full_name': 'tonwhales/wallet',
#       'private': False,
#       'owner': {'login': 'tonwhales',
#        'id': 94789130,
#        'node_id': 'O_kgDOBaZeCg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/94789130?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tonwhales',
#        'html_url': 'https://github.com/tonwhales',
#        'followers_url': 'https://api.github.com/users/tonwhales/followers',
#        'following_url': 'https://api.github.com/users/tonwhales/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tonwhales/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tonwhales/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tonwhales/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tonwhales/orgs',
#        'repos_url': 'https://api.github.com/users/tonwhales/repos',
#        'events_url': 'https://api.github.com/users/tonwhales/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tonwhales/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/tonwhales/wallet',
#       'description': 'Fast, secure and modern wallet for TONCOIN',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tonwhales/wallet',
#       'forks_url': 'https://api.github.com/repos/tonwhales/wallet/forks',
#       'keys_url': 'https://api.github.com/repos/tonwhales/wallet/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tonwhales/wallet/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tonwhales/wallet/teams',
#       'hooks_url': 'https://api.github.com/repos/tonwhales/wallet/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tonwhales/wallet/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tonwhales/wallet/events',
#       'assignees_url': 'https://api.github.com/repos/tonwhales/wallet/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tonwhales/wallet/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tonwhales/wallet/tags',
#       'blobs_url': 'https://api.github.com/repos/tonwhales/wallet/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tonwhales/wallet/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tonwhales/wallet/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tonwhales/wallet/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tonwhales/wallet/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tonwhales/wallet/languages',
#       'stargazers_url': 'https://api.github.com/repos/tonwhales/wallet/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tonwhales/wallet/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tonwhales/wallet/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tonwhales/wallet/subscription',
#       'commits_url': 'https://api.github.com/repos/tonwhales/wallet/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tonwhales/wallet/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tonwhales/wallet/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tonwhales/wallet/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tonwhales/wallet/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tonwhales/wallet/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tonwhales/wallet/merges',
#       'archive_url': 'https://api.github.com/repos/tonwhales/wallet/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tonwhales/wallet/downloads',
#       'issues_url': 'https://api.github.com/repos/tonwhales/wallet/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tonwhales/wallet/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tonwhales/wallet/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tonwhales/wallet/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tonwhales/wallet/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tonwhales/wallet/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tonwhales/wallet/deployments',
#       'created_at': '2021-12-26T20:22:45Z',
#       'updated_at': '2025-04-03T10:01:00Z',
#       'pushed_at': '2025-04-03T14:55:12Z',
#       'git_url': 'git://github.com/tonwhales/wallet.git',
#       'ssh_url': 'git@github.com:tonwhales/wallet.git',
#       'clone_url': 'https://github.com/tonwhales/wallet.git',
#       'svn_url': 'https://github.com/tonwhales/wallet',
#       'homepage': '',
#       'size': 83588,
#       'stargazers_count': 160,
#       'watchers_count': 160,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 59,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 59,
#       'open_issues': 14,
#       'watchers': 160,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tonwhales/wallet/pulls/1478'},
#      'html': {'href': 'https://github.com/tonwhales/wallet/pull/1478'},
#      'issue': {'href': 'https://api.github.com/repos/tonwhales/wallet/issues/1478'},
#      'comments': {'href': 'https://api.github.com/repos/tonwhales/wallet/issues/1478/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tonwhales/wallet/pulls/1478/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tonwhales/wallet/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tonwhales/wallet/pulls/1478/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tonwhales/wallet/statuses/2b57370aadbaa880b86ad18228b5ebb1495a3c37'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'vzhovnitsky',
#      'id': 32094306,
#      'node_id': 'MDQ6VXNlcjMyMDk0MzA2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/32094306?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vzhovnitsky',
#      'html_url': 'https://github.com/vzhovnitsky',
#      'followers_url': 'https://api.github.com/users/vzhovnitsky/followers',
#      'following_url': 'https://api.github.com/users/vzhovnitsky/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vzhovnitsky/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vzhovnitsky/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vzhovnitsky/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vzhovnitsky/orgs',
#      'repos_url': 'https://api.github.com/users/vzhovnitsky/repos',
#      'events_url': 'https://api.github.com/users/vzhovnitsky/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vzhovnitsky/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 94789130,
#    'login': 'tonwhales',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tonwhales',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94789130?'}},
#  {'id': '48290683386',
#   'type': 'DeleteEvent',
#   'actor': {'id': 9049490,
#    'login': 'giuliocalzolari',
#    'display_login': 'giuliocalzolari',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/giuliocalzolari',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9049490?'},
#   'repo': {'id': 897856350,
#    'name': 'datarobot-oss/helm-datarobot-plugin',
#    'url': 'https://api.github.com/repos/datarobot-oss/helm-datarobot-plugin'},
#   'payload': {'ref': 'giuliocalzo/layer-upload',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 112586857,
#    'login': 'datarobot-oss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/datarobot-oss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112586857?'}},
#  {'id': '48290683345',
#   'type': 'PushEvent',
#   'actor': {'id': 73132660,
#    'login': 'Sergey-Kozlov-developer',
#    'display_login': 'Sergey-Kozlov-developer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sergey-Kozlov-developer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73132660?'},
#   'repo': {'id': 950109393,
#    'name': 'Sergey-Kozlov-developer/php-less',
#    'url': 'https://api.github.com/repos/Sergey-Kozlov-developer/php-less'},
#   'payload': {'repository_id': 950109393,
#    'push_id': 23549046810,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'abbca34a730d4ab449345fa3f8dfe39eef8ed476',
#    'before': '807769454b11e44ab36576b8f3a3b85b60019ae4',
#    'commits': [{'sha': 'abbca34a730d4ab449345fa3f8dfe39eef8ed476',
#      'author': {'email': 'vmf.serge.kozlov@gmail.com',
#       'name': 'Sergey-Kozlov-developer'},
#      'message': 'edit films',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sergey-Kozlov-developer/php-less/commits/abbca34a730d4ab449345fa3f8dfe39eef8ed476'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683406',
#   'type': 'DeleteEvent',
#   'actor': {'id': 5241828,
#    'login': 'bigfishdesign13',
#    'display_login': 'bigfishdesign13',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bigfishdesign13',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5241828?'},
#   'repo': {'id': 192781213,
#    'name': 'NYPL/nypl-design-system',
#    'url': 'https://api.github.com/repos/NYPL/nypl-design-system'},
#   'payload': {'ref': 'DSD-1935/definition-list-spacing',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 944604,
#    'login': 'NYPL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NYPL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/944604?'}},
#  {'id': '48290683291',
#   'type': 'PushEvent',
#   'actor': {'id': 71253089,
#    'login': 'Dorian2002',
#    'display_login': 'Dorian2002',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dorian2002',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71253089?'},
#   'repo': {'id': 897395034,
#    'name': 'Tractorou24/BloodTear',
#    'url': 'https://api.github.com/repos/Tractorou24/BloodTear'},
#   'payload': {'repository_id': 897395034,
#    'push_id': 23549045463,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ab5bf19b84d1c60ca600118cb523b46fa20f3eb6',
#    'before': '1b9fb48571059c9b55bf9e7445db1c1c9ed7b973',
#    'commits': [{'sha': 'ab5bf19b84d1c60ca600118cb523b46fa20f3eb6',
#      'author': {'email': '41238114+math3133@users.noreply.github.com',
#       'name': 'math3133'},
#      'message': 'Game art 14 (#87)\n\nCo-authored-by: Shemoon2 <162476130+Shemoon2@users.noreply.github.com>\nCo-authored-by: AndrezRemi <56161114+AndrezRemi@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Tractorou24/BloodTear/commits/ab5bf19b84d1c60ca600118cb523b46fa20f3eb6'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683297',
#   'type': 'PushEvent',
#   'actor': {'id': 73880918,
#    'login': 'CloudPipeline-Auto',
#    'display_login': 'CloudPipeline-Auto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CloudPipeline-Auto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73880918?'},
#   'repo': {'id': 174065041,
#    'name': 'epam/cloud-pipeline',
#    'url': 'https://api.github.com/repos/epam/cloud-pipeline'},
#   'payload': {'repository_id': 174065041,
#    'push_id': 23549046712,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '00a5038339cb884b7039bb813dcf803158c2c19e',
#    'before': '3e057dbfd22282739de4afa1a5bc6b09cbc62d7e',
#    'commits': [{'sha': '00a5038339cb884b7039bb813dcf803158c2c19e',
#      'author': {'email': 'appveyor@appveyor-ci.org', 'name': 'Appveyor'},
#      'message': 'Docs update via Appveyor Build 18107',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/epam/cloud-pipeline/commits/00a5038339cb884b7039bb813dcf803158c2c19e'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 1589802,
#    'login': 'epam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/epam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1589802?'}},
#  {'id': '48290683300',
#   'type': 'PushEvent',
#   'actor': {'id': 78306449,
#    'login': 'tomxi1997',
#    'display_login': 'tomxi1997',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tomxi1997',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78306449?'},
#   'repo': {'id': 959907215,
#    'name': 'tomxi1997/lxc-android28',
#    'url': 'https://api.github.com/repos/tomxi1997/lxc-android28'},
#   'payload': {'repository_id': 959907215,
#    'push_id': 23549046861,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f021ade2af6c6688f6c6c1ba7052b2b995bf1dfe',
#    'before': '6823bbe6589196fcbd10b0e14d5ae9ca4b677caa',
#    'commits': [{'sha': 'f021ade2af6c6688f6c6c1ba7052b2b995bf1dfe',
#      'author': {'email': 'tomxi1997@gmail.com', 'name': 'tomxi1997'},
#      'message': '1st',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tomxi1997/lxc-android28/commits/f021ade2af6c6688f6c6c1ba7052b2b995bf1dfe'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683288',
#   'type': 'PushEvent',
#   'actor': {'id': 198884339,
#    'login': 'a7isss',
#    'display_login': 'a7isss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/a7isss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/198884339?'},
#   'repo': {'id': 953020227,
#    'name': 'a7isss/hospital',
#    'url': 'https://api.github.com/repos/a7isss/hospital'},
#   'payload': {'repository_id': 953020227,
#    'push_id': 23549046911,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ae6bced78ea567a4d19eab6d67771a4c6fa358a5',
#    'before': 'af5fe91985e898cccf0abe8a583670eebef1b234',
#    'commits': [{'sha': 'ae6bced78ea567a4d19eab6d67771a4c6fa358a5',
#      'author': {'email': '10.younis@gmail.com', 'name': 'A7isss'},
#      'message': 'login fix 37',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/a7isss/hospital/commits/ae6bced78ea567a4d19eab6d67771a4c6fa358a5'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683273',
#   'type': 'PushEvent',
#   'actor': {'id': 19785983,
#    'login': 'BirdHighway',
#    'display_login': 'BirdHighway',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BirdHighway',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19785983?'},
#   'repo': {'id': 451515611,
#    'name': 'blendededge/soap-component-oih',
#    'url': 'https://api.github.com/repos/blendededge/soap-component-oih'},
#   'payload': {'repository_id': 451515611,
#    'push_id': 23549046681,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7f8509415b99c6824170818064926b6179d3797c',
#    'before': 'c8de8acf3c58af8d73359a3806b1640aa3131361',
#    'commits': [{'sha': '077c81ffe8c020914967a69b05dcf3d82095ba71',
#      'author': {'email': 'shh2112@gmail.com', 'name': 'Stephen Hyde'},
#      'message': 'Upgrade ferryman-extensions to 2.1.0',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/blendededge/soap-component-oih/commits/077c81ffe8c020914967a69b05dcf3d82095ba71'},
#     {'sha': '7f8509415b99c6824170818064926b6179d3797c',
#      'author': {'email': 'shh2112@gmail.com', 'name': 'Stephen Hyde'},
#      'message': 'Merge pull request #46 from blendededge/upgrade-ferryman-extensions-2.1.0\n\nUpgrade ferryman-extensions to 2.1.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/blendededge/soap-component-oih/commits/7f8509415b99c6824170818064926b6179d3797c'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 73839680,
#    'login': 'blendededge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/blendededge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73839680?'}},
#  {'id': '48290683256',
#   'type': 'PushEvent',
#   'actor': {'id': 165777684,
#    'login': 'wubomir',
#    'display_login': 'wubomir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wubomir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/165777684?'},
#   'repo': {'id': 940612372,
#    'name': 'wubomir/wubomir.github.io',
#    'url': 'https://api.github.com/repos/wubomir/wubomir.github.io'},
#   'payload': {'repository_id': 940612372,
#    'push_id': 23549046869,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f646ff57d27cc09f444d05ceccacea9c4434c5ae',
#    'before': '77cadef86c2561ed3e81757e3f562b0c064e4421',
#    'commits': [{'sha': 'f646ff57d27cc09f444d05ceccacea9c4434c5ae',
#      'author': {'email': '165777684+wubomir@users.noreply.github.com',
#       'name': 'wubomir'},
#      'message': 'Update summary.csv - 2025-04-03 14:55:10 UTC',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wubomir/wubomir.github.io/commits/f646ff57d27cc09f444d05ceccacea9c4434c5ae'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683249',
#   'type': 'PushEvent',
#   'actor': {'id': 160240294,
#    'login': 'MartinShift',
#    'display_login': 'MartinShift',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MartinShift',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/160240294?'},
#   'repo': {'id': 959877273,
#    'name': 'MartinShift/lambda11',
#    'url': 'https://api.github.com/repos/MartinShift/lambda11'},
#   'payload': {'repository_id': 959877273,
#    'push_id': 23549046677,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1aa59f614c71902c24fa66c84e1e8f3c6515575e',
#    'before': '1d2cded24a3280108ada53784ad87fe350706fb9',
#    'commits': [{'sha': '1aa59f614c71902c24fa66c84e1e8f3c6515575e',
#      'author': {'email': 'mori.steamer@gmail.com', 'name': 'MartinShift'},
#      'message': 'node 2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MartinShift/lambda11/commits/1aa59f614c71902c24fa66c84e1e8f3c6515575e'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683271',
#   'type': 'PushEvent',
#   'actor': {'id': 98326467,
#    'login': 'domibron',
#    'display_login': 'domibron',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/domibron',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98326467?'},
#   'repo': {'id': 937397497,
#    'name': 'domibron/networkingModule',
#    'url': 'https://api.github.com/repos/domibron/networkingModule'},
#   'payload': {'repository_id': 937397497,
#    'push_id': 23549046813,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '55fd5d2f32685dbdadb204a5fcdb131189950159',
#    'before': '19c425f677beb16c2c5252e12107d8945cf2dd62',
#    'commits': [{'sha': '55fd5d2f32685dbdadb204a5fcdb131189950159',
#      'author': {'email': 'dommcneill@outlook.com', 'name': 'DM'},
#      'message': 'working on dealing with pre game and game scenes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/domibron/networkingModule/commits/55fd5d2f32685dbdadb204a5fcdb131189950159'}]},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z'},
#  {'id': '48290683267',
#   'type': 'CreateEvent',
#   'actor': {'id': 416501,
#    'login': 'onionpsy',
#    'display_login': 'onionpsy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onionpsy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/416501?'},
#   'repo': {'id': 959910870,
#    'name': 'CodeIntelligenceTesting/libredwg',
#    'url': 'https://api.github.com/repos/CodeIntelligenceTesting/libredwg'},
#   'payload': {'ref': 'fuzzing-setup',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': "Official mirror of libredwg. With CI hooks and nightly releases. PR's ok",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 64019151,
#    'login': 'CodeIntelligenceTesting',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CodeIntelligenceTesting',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64019151?'}},
#  {'id': '48290683246',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 16239342,
#    'login': 'pyup-bot',
#    'display_login': 'pyup-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pyup-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16239342?'},
#   'repo': {'id': 249242315,
#    'name': 'thiagocaiubi/COVID-19',
#    'url': 'https://api.github.com/repos/thiagocaiubi/COVID-19'},
#   'payload': {'action': 'opened',
#    'number': 1762,
#    'pull_request': {'url': 'https://api.github.com/repos/thiagocaiubi/COVID-19/pulls/1762',
#     'id': 2437323945,
#     'node_id': 'PR_kwDODtsiy86RRpyp',
#     'html_url': 'https://github.com/thiagocaiubi/COVID-19/pull/1762',
#     'diff_url': 'https://github.com/thiagocaiubi/COVID-19/pull/1762.diff',
#     'patch_url': 'https://github.com/thiagocaiubi/COVID-19/pull/1762.patch',
#     'issue_url': 'https://api.github.com/repos/thiagocaiubi/COVID-19/issues/1762',
#     'number': 1762,
#     'state': 'open',
#     'locked': False,
#     'title': 'Scheduled daily dependency update on Thursday',
#     'user': {'login': 'pyup-bot',
#      'id': 16239342,
#      'node_id': 'MDQ6VXNlcjE2MjM5MzQy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16239342?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pyup-bot',
#      'html_url': 'https://github.com/pyup-bot',
#      'followers_url': 'https://api.github.com/users/pyup-bot/followers',
#      'following_url': 'https://api.github.com/users/pyup-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pyup-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pyup-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pyup-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pyup-bot/orgs',
#      'repos_url': 'https://api.github.com/users/pyup-bot/repos',
#      'events_url': 'https://api.github.com/users/pyup-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pyup-bot/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': '\n\n\n\n\n### Update [bokeh](https://pypi.org/project/bokeh) from **2.0.0** to **3.7.2**.\n\n\n<details>\n  <summary>Changelog</summary>\n  \n  \n   ### 3.6\n   ```\n   --------------------\n  * bugfixes:\n    - 4951 ModelExtensions - all resources from a whole module are loaded\n    - 7524 GroupFilter only accepts strings\n    - 13827 [component: bokehjs] [BUG] Lack of range expansion when there remains unbounded directions, even when `maintain_focus=False`\n    - 13886 [component: bokehjs] [BUG] NPM package has types (*.d.ts) in incorrect location\n    - 13957 [component: bokehjs] Explicit selection glyph example broken\n    - 13959 [BUG] Reset Tool Error in Bokeh Gridplot with Single Plot\n    - 13964 [component: bokehjs] [BUG] page won&#x27;t render if CustomJS args has a dict with key &quot;constructor&quot;\n    - 13965 [component: bokehjs] [BUG] CategoricalSlider shows ‘undefined’ value and skip that value\n    - 13972 BOKEH_MINIFIED not working\n    - 13984 [component: tests] [BUG] Deprecation warning treated as error in pytest hook\n    - 14014 [component: bokehjs] [BUG] StringFormatter `nan_format` seems broken \n    - 14054 [component: bokehjs] [BUG] Custom hover tooltip on image plot shows all the image data.\n    - 14058 [component: bokehjs] [BUG] Clearing selection with ESC only works on first selection tool\n    - 14068 [component: bokehjs] [BUG] Unable to change figures displayed by altering children attribute of gridplot (or other layout classes) in JS callback\n    - 14072 [component: bokehjs] [BUG] Spinner input not responding to wheel event\n    - 13968 [component: docs] fix indentation in `offset` parameter for `Title`\n    - 14038 [component: bokehjs] Allow `is_equal(0, -0)` to be true to match `===`\n    - 14055 [component: docs] fix some typos\n    - 14065 [component: build] Generate correct `*.d.ts` files for CSS modules\n\n  * features:\n    - 601 [component: bokehjs] Add support for click events on categorical axes\n    - 11104 [component: bokehjs] [FEATURE] Option for DataTable column sorting to place NaNs last\n    - 13130 [component: bokehjs] Add CustomJSTicker\n    - 13893 [component: bokehjs] [FEATURE] Custom sorting of columns in a table\n    - 13905 [component: bokehjs] [FEATURE] triangle relative size by data units\n    - 13921 [FEATURE] Attach ScaleBar to subplot range\n    - 14035 [component: bokehjs] Add WebGL implementation for Ngon glyph\n    - 14031 [component: bokehjs] Add &quot;open image in a new tab&quot; mode to save tool\n    - 14033 Add support for click-style pan tools\n\n  * tasks:\n    - 12303 [FEATURE] Improved error message on token expiry\n    - 13835 [FEATURE] NumPy 2.0 support\n    - 13960 [component: docs] Remove sampledata download in contributing guide\n    - 13963 [FEATURE] Add a conda channel for rc releases \n    - 13969 [component: bokehjs] [BUG] Plots fail in Firefox 115.12.0esr (64-bit)\n    - 13946 [component: build] Upgrade to TypeScript 5.5\n    - 13977 [component: bokehjs] Make `GlyphRenderer` generic in glyph type and remove a lot of `any` types\n    - 13992 Remove docker and old integration tests cruft\n    - 14019 [component: docs] Python docstring argument fixes\n    - 14021 [component: docs] Fix HTML/CSS warning for palette group detail\n    - 14023 [component: docs] Remove outdated known issues list from BokehJS docs\n    - 14024 [component: docs] Update setup and testing docs dev guide\n    - 14037 [component: bokehjs] Clean up factor range and add factor method\n    - 14048 [component: bokehjs] Add missing `abstract` modifier to classes\n    - 14051 [component: bokehjs] Use pseudo type members to avoid casting\n    - 14052 [component: bokehjs] Make `PaletteSelect` use stylehseets instead of inline styles\n    - 14056 [component: bokehjs] Upgrade to TypeScript 5.6\n    - 14064 [component: build] Add `script:watch` task for incremental builds\n    - 14067 [component: build] Upgrade `types/node` and fix npm audit&#x27;s concerns\n    - 14071 ...
#     'created_at': '2025-04-03T14:55:11Z',
#     'updated_at': '2025-04-03T14:55:11Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/thiagocaiubi/COVID-19/pulls/1762/commits',
# ...
#       'color': 'eeffee',
#       'default': False,
#       'description': ''},
#      {'id': 1955058054,
#       'node_id': 'MDU6TGFiZWwxOTU1MDU4MDU0',
#       'url': 'https://api.github.com/repos/NixOS/nixpkgs/labels/10.rebuild-linux:%201',
#       'name': '10.rebuild-linux: 1',
#       'color': 'eeffee',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/395746/commits',
#     'review_comments_url': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/395746/comments',
#     'review_comment_url': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/395746/comments',
#     'statuses_url': 'https://api.github.com/repos/NixOS/nixpkgs/statuses/a9bd19deb37dd439c04399114cc969be2204f056',
#     'head': {'label': 'amarshall:git-cinnabar-update',
#      'ref': 'git-cinnabar-update',
#      'sha': 'a9bd19deb37dd439c04399114cc969be2204f056',
#      'user': {'login': 'amarshall',
#       'id': 153175,
#       'node_id': 'MDQ6VXNlcjE1MzE3NQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/153175?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/amarshall',
#       'html_url': 'https://github.com/amarshall',
#       'followers_url': 'https://api.github.com/users/amarshall/followers',
#       'following_url': 'https://api.github.com/users/amarshall/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/amarshall/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/amarshall/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/amarshall/subscriptions',
#       'organizations_url': 'https://api.github.com/users/amarshall/orgs',
#       'repos_url': 'https://api.github.com/users/amarshall/repos',
#       'events_url': 'https://api.github.com/users/amarshall/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/amarshall/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 422590488,
#       'node_id': 'R_kgDOGTA4GA',
#       'name': 'nixpkgs',
#       'full_name': 'amarshall/nixpkgs',
#       'private': False,
#       'owner': {'login': 'amarshall',
#        'id': 153175,
#        'node_id': 'MDQ6VXNlcjE1MzE3NQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/153175?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/amarshall',
#        'html_url': 'https://github.com/amarshall',
#        'followers_url': 'https://api.github.com/users/amarshall/followers',
#        'following_url': 'https://api.github.com/users/amarshall/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/amarshall/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/amarshall/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/amarshall/subscriptions',
#        'organizations_url': 'https://api.github.com/users/amarshall/orgs',
#        'repos_url': 'https://api.github.com/users/amarshall/repos',
#        'events_url': 'https://api.github.com/users/amarshall/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/amarshall/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/amarshall/nixpkgs',
#       'description': 'Nix Packages collection',
#       'fork': True,
#       'url': 'https://api.github.com/repos/amarshall/nixpkgs',
#       'forks_url': 'https://api.github.com/repos/amarshall/nixpkgs/forks',
#       'keys_url': 'https://api.github.com/repos/amarshall/nixpkgs/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/amarshall/nixpkgs/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/amarshall/nixpkgs/teams',
#       'hooks_url': 'https://api.github.com/repos/amarshall/nixpkgs/hooks',
#       'issue_events_url': 'https://api.github.com/repos/amarshall/nixpkgs/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/amarshall/nixpkgs/events',
#       'assignees_url': 'https://api.github.com/repos/amarshall/nixpkgs/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/amarshall/nixpkgs/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/amarshall/nixpkgs/tags',
#       'blobs_url': 'https://api.github.com/repos/amarshall/nixpkgs/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/amarshall/nixpkgs/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/amarshall/nixpkgs/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/amarshall/nixpkgs/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/amarshall/nixpkgs/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/amarshall/nixpkgs/languages',
#       'stargazers_url': 'https://api.github.com/repos/amarshall/nixpkgs/stargazers',
#       'contributors_url': 'https://api.github.com/repos/amarshall/nixpkgs/contributors',
#       'subscribers_url': 'https://api.github.com/repos/amarshall/nixpkgs/subscribers',
#       'subscription_url': 'https://api.github.com/repos/amarshall/nixpkgs/subscription',
#       'commits_url': 'https://api.github.com/repos/amarshall/nixpkgs/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/amarshall/nixpkgs/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/amarshall/nixpkgs/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/amarshall/nixpkgs/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/amarshall/nixpkgs/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/amarshall/nixpkgs/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/amarshall/nixpkgs/merges',
#       'archive_url': 'https://api.github.com/repos/amarshall/nixpkgs/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/amarshall/nixpkgs/downloads',
#       'issues_url': 'https://api.github.com/repos/amarshall/nixpkgs/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/amarshall/nixpkgs/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/amarshall/nixpkgs/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/amarshall/nixpkgs/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/amarshall/nixpkgs/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/amarshall/nixpkgs/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/amarshall/nixpkgs/deployments',
#       'created_at': '2021-10-29T13:43:17Z',
#       'updated_at': '2024-11-15T13:49:25Z',
#       'pushed_at': '2025-04-03T12:39:19Z',
#       'git_url': 'git://github.com/amarshall/nixpkgs.git',
#       'ssh_url': 'git@github.com:amarshall/nixpkgs.git',
#       'clone_url': 'https://github.com/amarshall/nixpkgs.git',
#       'svn_url': 'https://github.com/amarshall/nixpkgs',
#       'homepage': '',
#       'size': 4722646,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Nix',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'NixOS:master',
#      'ref': 'master',
#      'sha': '8ecbe4aa375774ea3c9963f19469329735aa24eb',
#      'user': {'login': 'NixOS',
#       'id': 487568,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ4NzU2OA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/487568?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/NixOS',
#       'html_url': 'https://github.com/NixOS',
#       'followers_url': 'https://api.github.com/users/NixOS/followers',
#       'following_url': 'https://api.github.com/users/NixOS/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/NixOS/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/NixOS/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/NixOS/subscriptions',
#       'organizations_url': 'https://api.github.com/users/NixOS/orgs',
#       'repos_url': 'https://api.github.com/users/NixOS/repos',
#       'events_url': 'https://api.github.com/users/NixOS/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/NixOS/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 4542716,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0NTQyNzE2',
#       'name': 'nixpkgs',
#       'full_name': 'NixOS/nixpkgs',
#       'private': False,
#       'owner': {'login': 'NixOS',
#        'id': 487568,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ4NzU2OA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/487568?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/NixOS',
#        'html_url': 'https://github.com/NixOS',
#        'followers_url': 'https://api.github.com/users/NixOS/followers',
#        'following_url': 'https://api.github.com/users/NixOS/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/NixOS/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/NixOS/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/NixOS/subscriptions',
#        'organizations_url': 'https://api.github.com/users/NixOS/orgs',
#        'repos_url': 'https://api.github.com/users/NixOS/repos',
#        'events_url': 'https://api.github.com/users/NixOS/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/NixOS/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/NixOS/nixpkgs',
#       'description': 'Nix Packages collection & NixOS',
#       'fork': False,
#       'url': 'https://api.github.com/repos/NixOS/nixpkgs',
#       'forks_url': 'https://api.github.com/repos/NixOS/nixpkgs/forks',
#       'keys_url': 'https://api.github.com/repos/NixOS/nixpkgs/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/NixOS/nixpkgs/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/NixOS/nixpkgs/teams',
#       'hooks_url': 'https://api.github.com/repos/NixOS/nixpkgs/hooks',
#       'issue_events_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/NixOS/nixpkgs/events',
#       'assignees_url': 'https://api.github.com/repos/NixOS/nixpkgs/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/NixOS/nixpkgs/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/NixOS/nixpkgs/tags',
#       'blobs_url': 'https://api.github.com/repos/NixOS/nixpkgs/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/NixOS/nixpkgs/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/NixOS/nixpkgs/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/NixOS/nixpkgs/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/NixOS/nixpkgs/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/NixOS/nixpkgs/languages',
#       'stargazers_url': 'https://api.github.com/repos/NixOS/nixpkgs/stargazers',
#       'contributors_url': 'https://api.github.com/repos/NixOS/nixpkgs/contributors',
#       'subscribers_url': 'https://api.github.com/repos/NixOS/nixpkgs/subscribers',
#       'subscription_url': 'https://api.github.com/repos/NixOS/nixpkgs/subscription',
#       'commits_url': 'https://api.github.com/repos/NixOS/nixpkgs/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/NixOS/nixpkgs/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/NixOS/nixpkgs/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/NixOS/nixpkgs/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/NixOS/nixpkgs/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/NixOS/nixpkgs/merges',
#       'archive_url': 'https://api.github.com/repos/NixOS/nixpkgs/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/NixOS/nixpkgs/downloads',
#       'issues_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/NixOS/nixpkgs/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/NixOS/nixpkgs/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/NixOS/nixpkgs/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/NixOS/nixpkgs/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/NixOS/nixpkgs/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/NixOS/nixpkgs/deployments',
#       'created_at': '2012-06-04T02:49:46Z',
#       'updated_at': '2025-04-03T14:43:58Z',
#       'pushed_at': '2025-04-03T14:39:31Z',
#       'git_url': 'git://github.com/NixOS/nixpkgs.git',
#       'ssh_url': 'git@github.com:NixOS/nixpkgs.git',
#       'clone_url': 'https://github.com/NixOS/nixpkgs.git',
#       'svn_url': 'https://github.com/NixOS/nixpkgs',
#       'homepage': '',
#       'size': 5010581,
#       'stargazers_count': 19888,
#       'watchers_count': 19888,
#       'language': 'Nix',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 15335,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16873,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest', 'linux', 'nix', 'nixos', 'nixpkgs'],
#       'visibility': 'public',
#       'forks': 15335,
#       'open_issues': 16873,
#       'watchers': 19888,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/395746'},
#      'html': {'href': 'https://github.com/NixOS/nixpkgs/pull/395746'},
#      'issue': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/issues/395746'},
#      'comments': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/issues/395746/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/395746/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/395746/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/NixOS/nixpkgs/statuses/a9bd19deb37dd439c04399114cc969be2204f056'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2025-04-03T14:55:13Z',
#   'org': {'id': 487568,
#    'login': 'NixOS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NixOS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/487568?'}}]

# %% [markdown]
# ### Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# Versão do github
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'
r = requests.get(url, headers=headers)

# %%
r.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2025-03-29T22:22:45Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 16,
#   'watchers_count': 16,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 375,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 375,
#   'open_issues': 3,
#   'watchers': 16,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2025-04-03T06:45:09Z',
#   'pushed_at': '2025-03-25T21:20:38Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 719,
#   'stargazers_count': 111,
#   'watchers_count': 111,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 36,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 26,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 36,
#   'open_issues': 26,
#   'watchers': 111,
#   'default_branch': 'main'},
#  {'id': 958141729,
#   'node_id': 'R_kgDOORwVIQ',
#   'name': 'ads-pao-amznjs-gtm-server-side-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-server-side-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/deployments',
#   'created_at': '2025-03-31T17:58:12Z',
#   'updated_at': '2025-03-31T19:00:33Z',
#   'pushed_at': '2025-03-31T19:00:28Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'homepage': None,
#   'size': 46,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 27,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 27,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2025-02-21T15:47:57Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1134,
#   'watchers_count': 1134,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1034,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1034,
#   'open_issues': 11,
#   'watchers': 1134,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2025-01-15T02:22:55Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 10,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
# ...
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/deployments',
#   'created_at': '2024-07-31T06:15:43Z',
#   'updated_at': '2025-03-11T10:49:01Z',
#   'pushed_at': '2025-03-11T10:49:59Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-api-sdk-ruby.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby',
#   'homepage': None,
#   'size': 50,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'main'},
#  {'id': 27617078,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYxNzA3OA==',
#   'name': 'amazon-pay-sdk-csharp',
#   'full_name': 'amzn/amazon-pay-sdk-csharp',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'description': 'Amazon Pay C# SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 40,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 40,
#   'open_issues': 11,
#   'watchers': 48,
#   'default_branch': 'master'},
#  {'id': 27605347,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYwNTM0Nw==',
#   'name': 'amazon-pay-sdk-java',
#   'full_name': 'amzn/amazon-pay-sdk-java',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'description': ' Amazon Pay Java SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-09-09T14:17:34Z',
#   'pushed_at': '2024-08-10T17:28:22Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 58,
#   'default_branch': 'master'}]

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como "limite de taxa". Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
token = 'meu_token'
headers['Authorization'] = f'Bearer {token}'

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url_amzn = f'{api_base_url}/users/{owner}/repos'
url_amzn
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 7):
    try:
        url_amzn_page = f'{url}?page={page_num}'
        response = requests.get(url_amzn_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2025-03-29T22:22:45Z',
#    'pushed_at': '2024-10-18T22:23:05Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 24,
#    'stargazers_count': 16,
#    'watchers_count': 16,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 375,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 375,
#    'open_issues': 3,
#    'watchers': 16,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2025-04-03T06:45:09Z',
#    'pushed_at': '2025-03-25T21:20:38Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 719,
#    'stargazers_count': 111,
#    'watchers_count': 111,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 36,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 26,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 36,
#    'open_issues': 26,
#    'watchers': 111,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 958141729,
#    'node_id': 'R_kgDOORwVIQ',
#    'name': 'ads-pao-amznjs-gtm-server-side-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-server-side-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/deployments',
#    'created_at': '2025-03-31T17:58:12Z',
#    'updated_at': '2025-03-31T19:00:33Z',
#    'pushed_at': '2025-03-31T19:00:28Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-server-side-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#    'homepage': None,
#    'size': 46,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2024-09-05T08:32:25Z',
#    'pushed_at': '2024-06-03T16:53:23Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 165,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2024-07-11T01:03:40Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 27,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 27,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2025-02-21T15:47:57Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1134,
#    'watchers_count': 1134,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1034,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1034,
#    'open_issues': 11,
#    'watchers': 1134,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2025-01-15T02:22:55Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 10,
#    'watchers_count': 10,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 10,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
# ...
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/deployments',
#    'created_at': '2019-10-04T18:00:25Z',
#    'updated_at': '2024-10-12T09:44:31Z',
#    'pushed_at': '2024-05-30T18:55:33Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-s7comm.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-s7comm.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-s7comm.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-s7comm',
#    'homepage': None,
#    'size': 36,
#    'stargazers_count': 41,
#    'watchers_count': 41,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 11,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 11,
#    'open_issues': 1,
#    'watchers': 41,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212874433,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzQ0MzM=',
#    'name': 'zeek-plugin-tds',
#    'full_name': 'amzn/zeek-plugin-tds',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Tabular Data Stream (TDS) protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-tds',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/deployments',
#    'created_at': '2019-10-04T18:01:45Z',
#    'updated_at': '2024-10-12T09:44:12Z',
#    'pushed_at': '2024-05-30T18:56:04Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-tds.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-tds.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-tds.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'homepage': '',
#    'size': 29,
#    'stargazers_count': 25,
#    'watchers_count': 25,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 12,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 12,
#    'open_issues': 0,
#    'watchers': 25,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 361620746,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2MjA3NDY=',
#    'name': 'zero-shot-rlhr',
#    'full_name': 'amzn/zero-shot-rlhr',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zero-shot-rlhr',
#    'forks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/deployments',
#    'created_at': '2021-04-26T04:49:11Z',
#    'updated_at': '2024-12-03T08:59:03Z',
#    'pushed_at': '2021-04-26T05:39:00Z',
#    'git_url': 'git://github.com/amzn/zero-shot-rlhr.git',
#    'ssh_url': 'git@github.com:amzn/zero-shot-rlhr.git',
#    'clone_url': 'https://github.com/amzn/zero-shot-rlhr.git',
#    'svn_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'homepage': None,
#    'size': 119,
#    'stargazers_count': 52,
#    'watchers_count': 52,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 1,
#    'watchers': 52,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
repos_list[5]
# Out:
# [{'id': 143745324,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNDM3NDUzMjQ=',
#   'name': 'tiny-attribution-generator',
#   'full_name': 'amzn/tiny-attribution-generator',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/tiny-attribution-generator',
#   'description': 'A small tool and library to create attribution notices from various formats',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/tiny-attribution-generator',
#   'forks_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/deployments',
#   'created_at': '2018-08-06T15:07:34Z',
#   'updated_at': '2023-07-15T20:02:15Z',
#   'pushed_at': '2020-12-23T22:35:18Z',
#   'git_url': 'git://github.com/amzn/tiny-attribution-generator.git',
#   'ssh_url': 'git@github.com:amzn/tiny-attribution-generator.git',
#   'clone_url': 'https://github.com/amzn/tiny-attribution-generator.git',
#   'svn_url': 'https://github.com/amzn/tiny-attribution-generator',
#   'homepage': 'https://www.npmjs.com/package/tiny-attribution-generator',
#   'size': 376,
#   'stargazers_count': 20,
#   'watchers_count': 20,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 15,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['licensing', 'nodejs', 'open-source-tooling'],
#   'visibility': 'public',
#   'forks': 15,
#   'open_issues': 1,
#   'watchers': 20,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 884496430,
#   'node_id': 'R_kgDONLhYLg',
#   'name': 'traffic-quality-smart-pixel-loader',
#   'full_name': 'amzn/traffic-quality-smart-pixel-loader',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader',
#   'forks_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/deployments',
#   'created_at': '2024-11-06T21:23:07Z',
#   'updated_at': '2024-11-22T07:45:08Z',
#   'pushed_at': '2024-11-22T07:35:43Z',
#   'git_url': 'git://github.com/amzn/traffic-quality-smart-pixel-loader.git',
#   'ssh_url': 'git@github.com:amzn/traffic-quality-smart-pixel-loader.git',
#   'clone_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader.git',
#   'svn_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader',
#   'homepage': None,
#   'size': 14,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'TypeScript',
#   'has_issues': False,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 431462375,
#   'node_id': 'R_kgDOGbeX5w',
#   'name': 'trans-encoder',
#   'full_name': 'amzn/trans-encoder',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/trans-encoder',
#   'description': 'Trans-Encoder: Unsupervised sentence-pair modelling through self- and mutual-distillations',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/trans-encoder',
#   'forks_url': 'https://api.github.com/repos/amzn/trans-encoder/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/trans-encoder/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/trans-encoder/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/trans-encoder/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/trans-encoder/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/trans-encoder/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/trans-encoder/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/trans-encoder/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/trans-encoder/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/trans-encoder/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/trans-encoder/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/trans-encoder/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/trans-encoder/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/trans-encoder/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/trans-encoder/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/trans-encoder/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/trans-encoder/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/trans-encoder/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/trans-encoder/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/trans-encoder/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/trans-encoder/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/trans-encoder/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/trans-encoder/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/trans-encoder/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/trans-encoder/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/trans-encoder/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/trans-encoder/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/trans-encoder/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/trans-encoder/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/trans-encoder/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/trans-encoder/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/trans-encoder/deployments',
#   'created_at': '2021-11-24T11:44:32Z',
#   'updated_at': '2025-01-11T09:08:02Z',
#   'pushed_at': '2024-05-30T18:51:20Z',
#   'git_url': 'git://github.com/amzn/trans-encoder.git',
#   'ssh_url': 'git@github.com:amzn/trans-encoder.git',
#   'clone_url': 'https://github.com/amzn/trans-encoder.git',
#   'svn_url': 'https://github.com/amzn/trans-encoder',
#   'homepage': '',
#   'size': 45,
#   'stargazers_count': 132,
#   'watchers_count': 132,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 16,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 16,
#   'open_issues': 3,
#   'watchers': 132,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 638205169,
#   'node_id': 'R_kgDOJgo88Q',
#   'name': 'user-satisfaction-modeling',
#   'full_name': 'amzn/user-satisfaction-modeling',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/user-satisfaction-modeling',
#   'description': 'Codebase for the paper "Schema-guided User Satisfaction Modeling for Task-oriented Dialogues"',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling',
#   'forks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/deployments',
#   'created_at': '2023-05-09T09:52:46Z',
#   'updated_at': '2024-10-09T14:18:49Z',
#   'pushed_at': '2024-10-09T14:18:45Z',
#   'git_url': 'git://github.com/amzn/user-satisfaction-modeling.git',
#   'ssh_url': 'git@github.com:amzn/user-satisfaction-modeling.git',
#   'clone_url': 'https://github.com/amzn/user-satisfaction-modeling.git',
#   'svn_url': 'https://github.com/amzn/user-satisfaction-modeling',
#   'homepage': '',
#   'size': 25,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 3,
#   'watchers': 11,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 271956469,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzE5NTY0Njk=',
#   'name': 'workspace-resolver',
#   'full_name': 'amzn/workspace-resolver',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/workspace-resolver',
#   'description': 'Utility for development on multiple library packages in a workspace',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/workspace-resolver',
#   'forks_url': 'https://api.github.com/repos/amzn/workspace-resolver/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/workspace-resolver/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/workspace-resolver/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/workspace-resolver/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/workspace-resolver/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/workspace-resolver/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/workspace-resolver/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/workspace-resolver/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/workspace-resolver/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/workspace-resolver/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/workspace-resolver/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/workspace-resolver/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/workspace-resolver/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/workspace-resolver/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/workspace-resolver/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/workspace-resolver/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/workspace-resolver/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/workspace-resolver/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/workspace-resolver/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/workspace-resolver/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/workspace-resolver/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/workspace-resolver/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/workspace-resolver/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/workspace-resolver/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/workspace-resolver/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/workspace-resolver/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/workspace-resolver/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/workspace-resolver/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/workspace-resolver/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/workspace-resolver/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/workspace-resolver/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/workspace-resolver/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/workspace-resolver/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/workspace-resolver/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/workspace-resolver/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/workspace-resolver/deployments',
#   'created_at': '2020-06-13T06:48:39Z',
#   'updated_at': '2024-08-10T09:58:46Z',
#   'pushed_at': '2023-07-18T23:02:46Z',
#   'git_url': 'git://github.com/amzn/workspace-resolver.git',
#   'ssh_url': 'git@github.com:amzn/workspace-resolver.git',
#   'clone_url': 'https://github.com/amzn/workspace-resolver.git',
#   'svn_url': 'https://github.com/amzn/workspace-resolver',
#   'homepage': '',
#   'size': 495,
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 6,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 6,
#   'open_issues': 2,
#   'watchers': 6,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 756260026,
#   'node_id': 'R_kgDOLROcug',
#   'name': 'ws-vae',
#   'full_name': 'amzn/ws-vae',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ws-vae',
#   'description': 'Robust Weak Supervision with Variational Auto-Encoders. Use VAEs to perform weak supervision and provide superior robustness to the quality of the weak labels.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ws-vae',
#   'forks_url': 'https://api.github.com/repos/amzn/ws-vae/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ws-vae/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ws-vae/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ws-vae/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ws-vae/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ws-vae/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ws-vae/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ws-vae/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ws-vae/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ws-vae/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ws-vae/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ws-vae/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ws-vae/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ws-vae/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ws-vae/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ws-vae/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ws-vae/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ws-vae/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ws-vae/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ws-vae/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ws-vae/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ws-vae/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ws-vae/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ws-vae/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ws-vae/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ws-vae/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ws-vae/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ws-vae/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ws-vae/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ws-vae/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ws-vae/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ws-vae/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ws-vae/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ws-vae/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ws-vae/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ws-vae/deployments',
#   'created_at': '2024-02-12T10:03:32Z',
#   'updated_at': '2025-02-07T09:41:13Z',
#   'pushed_at': '2024-07-30T21:17:39Z',
#   'git_url': 'git://github.com/amzn/ws-vae.git',
#   'ssh_url': 'git@github.com:amzn/ws-vae.git',
#   'clone_url': 'https://github.com/amzn/ws-vae.git',
#   'svn_url': 'https://github.com/amzn/ws-vae',
#   'homepage': 'https://proceedings.mlr.press/v202/tonolini23a.html',
#   'size': 34,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 2,
#   'watchers': 1,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 139183633,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzkxODM2MzM=',
#   'name': 'xfer',
#   'full_name': 'amzn/xfer',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/xfer',
#   'description': 'Transfer Learning library for Deep Neural Networks.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/xfer',
#   'forks_url': 'https://api.github.com/repos/amzn/xfer/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/xfer/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/xfer/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/xfer/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/xfer/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/xfer/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/xfer/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/xfer/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/xfer/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/xfer/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/xfer/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/xfer/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/xfer/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/xfer/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/xfer/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/xfer/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/xfer/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/xfer/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/xfer/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/xfer/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/xfer/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/xfer/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/xfer/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/xfer/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/xfer/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/xfer/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/xfer/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/xfer/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/xfer/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/xfer/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/xfer/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/xfer/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/xfer/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/xfer/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/xfer/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/xfer/deployments',
#   'created_at': '2018-06-29T18:37:36Z',
#   'updated_at': '2025-03-12T02:00:38Z',
#   'pushed_at': '2023-07-17T03:37:21Z',
#   'git_url': 'git://github.com/amzn/xfer.git',
#   'ssh_url': 'git@github.com:amzn/xfer.git',
#   'clone_url': 'https://github.com/amzn/xfer.git',
#   'svn_url': 'https://github.com/amzn/xfer',
#   'homepage': None,
#   'size': 135812,
#   'stargazers_count': 255,
#   'watchers_count': 255,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 62,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 7,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['machine-learning',
#    'mxnet',
#    'neural-network',
#    'python',
#    'transfer-learning'],
#   'visibility': 'public',
#   'forks': 62,
#   'open_issues': 7,
#   'watchers': 255,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 212873101,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzMxMDE=',
#   'name': 'zeek-plugin-bacnet',
#   'full_name': 'amzn/zeek-plugin-bacnet',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/zeek-plugin-bacnet',
#   'description': 'Zeek network security monitor plugin that enables parsing of the BACnet standard building controls protocol',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet',
#   'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/deployments',
#   'created_at': '2019-10-04T17:54:21Z',
#   'updated_at': '2025-01-16T19:59:32Z',
#   'pushed_at': '2024-05-30T18:54:30Z',
#   'git_url': 'git://github.com/amzn/zeek-plugin-bacnet.git',
#   'ssh_url': 'git@github.com:amzn/zeek-plugin-bacnet.git',
#   'clone_url': 'https://github.com/amzn/zeek-plugin-bacnet.git',
#   'svn_url': 'https://github.com/amzn/zeek-plugin-bacnet',
#   'homepage': None,
#   'size': 56,
#   'stargazers_count': 31,
#   'watchers_count': 31,
#   'language': 'Zeek',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 12,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 19,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#   'visibility': 'public',
#   'forks': 12,
#   'open_issues': 19,
#   'watchers': 31,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 212873469,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzM0Njk=',
#   'name': 'zeek-plugin-enip',
#   'full_name': 'amzn/zeek-plugin-enip',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
# ...
#   'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/deployments',
#   'created_at': '2019-10-04T18:00:25Z',
#   'updated_at': '2024-10-12T09:44:31Z',
#   'pushed_at': '2024-05-30T18:55:33Z',
#   'git_url': 'git://github.com/amzn/zeek-plugin-s7comm.git',
#   'ssh_url': 'git@github.com:amzn/zeek-plugin-s7comm.git',
#   'clone_url': 'https://github.com/amzn/zeek-plugin-s7comm.git',
#   'svn_url': 'https://github.com/amzn/zeek-plugin-s7comm',
#   'homepage': None,
#   'size': 36,
#   'stargazers_count': 41,
#   'watchers_count': 41,
#   'language': 'Zeek',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 11,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#   'visibility': 'public',
#   'forks': 11,
#   'open_issues': 1,
#   'watchers': 41,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 212874433,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzQ0MzM=',
#   'name': 'zeek-plugin-tds',
#   'full_name': 'amzn/zeek-plugin-tds',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/zeek-plugin-tds',
#   'description': 'Zeek network security monitor plugin that enables parsing of the Tabular Data Stream (TDS) protocol',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/zeek-plugin-tds',
#   'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/deployments',
#   'created_at': '2019-10-04T18:01:45Z',
#   'updated_at': '2024-10-12T09:44:12Z',
#   'pushed_at': '2024-05-30T18:56:04Z',
#   'git_url': 'git://github.com/amzn/zeek-plugin-tds.git',
#   'ssh_url': 'git@github.com:amzn/zeek-plugin-tds.git',
#   'clone_url': 'https://github.com/amzn/zeek-plugin-tds.git',
#   'svn_url': 'https://github.com/amzn/zeek-plugin-tds',
#   'homepage': '',
#   'size': 29,
#   'stargazers_count': 25,
#   'watchers_count': 25,
#   'language': 'Zeek',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 12,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['security-tools', 'zeek', 'zeek-package'],
#   'visibility': 'public',
#   'forks': 12,
#   'open_issues': 0,
#   'watchers': 25,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 361620746,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2MjA3NDY=',
#   'name': 'zero-shot-rlhr',
#   'full_name': 'amzn/zero-shot-rlhr',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/zero-shot-rlhr',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/zero-shot-rlhr',
#   'forks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/deployments',
#   'created_at': '2021-04-26T04:49:11Z',
#   'updated_at': '2024-12-03T08:59:03Z',
#   'pushed_at': '2021-04-26T05:39:00Z',
#   'git_url': 'git://github.com/amzn/zero-shot-rlhr.git',
#   'ssh_url': 'git@github.com:amzn/zero-shot-rlhr.git',
#   'clone_url': 'https://github.com/amzn/zero-shot-rlhr.git',
#   'svn_url': 'https://github.com/amzn/zero-shot-rlhr',
#   'homepage': None,
#   'size': 119,
#   'stargazers_count': 52,
#   'watchers_count': 52,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 16,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 16,
#   'open_issues': 1,
#   'watchers': 52,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}}]

# %% [markdown]
# ### Transformando os dados

# %% [markdown]
# #### Nomes dos repositórios

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-server-side-template'

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])
repos_name
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples',
#  'amazon-hub-counter-sdk-java',
#  'amazon-hub-support',
#  'amazon-instant-access-sdk-java',
#  'amazon-instant-access-sdk-net',
#  'amazon-instant-access-sdk-php',
#  'amazon-instant-access-sdk-ruby',
#  'amazon-launcher-integration-cordova-plugin',
#  'amazon-marketing-stream-examples',
#  'amazon-mcf-plugin-for-magento-1',
#  'amazon-multi-token-completion',
#  'amazon-nearest-neighbor-through-ecc',
#  'amazon-pay-api-sdk-dotnet',
#  'amazon-pay-api-sdk-java',
#  'amazon-pay-api-sdk-nodejs',
#  'amazon-pay-api-sdk-php',
#  'amazon-pay-api-sdk-ruby',
#  'amazon-pay-sdk-csharp',
#  'amazon-pay-sdk-java',
#  'amazon-pay-sdk-php',
#  'amazon-pay-sdk-python',
#  'amazon-pay-sdk-ruby',
#  'amazon-pay-sdk-samples',
#  'amazon-payment-files-tools',
#  'amazon-payments-magento-2-plugin',
#  'amazon-ray',
#  'amazon-s3-gst-plugin',
#  'amazon-sidewalk-android-samples',
#  'amazon-sidewalk-ios-samples',
#  'amazon-succinct-doc-representation',
#  'amazon-template-library',
#  'amazon-weak-ner-needle',
#  'amigitenough',
#  'amzn-drivers',
#  'amzn-ec2-ena-utilities',
#  'armbench',
#  'auction-gym',
#  'augment-the-pairs-wacv2024',
#  'autotrail',
#  'aws-apigateway-client-lib',
#  'aws-sigv4-signing-samples',
#  'awsssmchaosrunner',
#  'basis-point-sets',
#  'BayesPE',
#  'buy-with-prime-cdk-constructs',
#  'buy-with-prime-monitoring-sample-cdk',
#  'chalet-charging-location-for-electric-trucks',
#  'computer-vision-basics-in-microsoft-excel',
#  'confident-sinkhorn-allocation',
#  'convolutional-handwriting-gan',
#  'cosearcher',
#  'credence-to-causal-estimation',
#  'data-jack-knife',
#  'debiased-balanced-interleaving',
#  'differential-privacy-bayesian-optimization',
#  'distance-assistant',
#  'drs-sample-android-app',
#  'drs-sample-ios-app',
#  'emukit-playground',
#  'eslint-plugin-no-date-parsing',
#  'exoplayer-amazon-port',
#  'explainable-text-vqa',
#  'extremely-efficient-query-encoder',
#  'faithful-data2text-cycle-training',
#  'fashion-attribute-disentanglement',
#  'fire-app-builder',
#  'firetv-sample-touch-app',
#  'ftv-integration-sdk-sample-app',
#  'ftv-livetv-sample-tv-app',
#  'gameon-sample-game-unity',
#  'gameon-starter-kit-unity',
#  'git-commit-template',
#  'glad',
#  'golang-gitoperations',
#  'halo-third-party-sdk-for-java',
#  'halo-third-party-sdk-for-node-js',
#  'halo-third-party-sdk-for-python',
#  'hawktracer',
#  'image-misspell-coling2020',
#  'image-to-recipe-transformers',
#  'informative-diverse-hard-negative-sampling',
#  'ion-cascading-config',
#  'ion-object-mapper-dotnet',
#  'jekyll-doc-project',
#  'kotlin-inject-anvil',
#  'kqr',
#  'lib-3d-scene-viewer',
#  'login-with-amazon-oscommerce',
#  'login-with-amazon-wordpress',
#  'media3-external-port',
#  'merlin-on-demand-callgraph',
#  'metalearn-leap',
#  'milan',
#  'MonitoringCustomMetrics',
#  'mrc-net-6d-pose',
#  'multiconer-baseline',
#  'multilingual-keyphrase-generation',
#  'multimodal-affinities',
#  'MXFusion',
#  'nimbus-jose-jwt_aws-kms-extension',
#  'node-jose_aws-kms-extension',
#  'openapi-swift-code-generate',
#  'orthogonal-additive-gaussian-processes',
#  'oss-attribution-builder',
#  'oss-contribution-tracker',
#  'oss-dashboard',
#  'pecos',
#  'pretraining-or-self-training',
#  'python-jose_aws-kms-extension',
#  'rdma-core',
#  'refuel-open-domain-qa',
#  'rete-thewebconf-2022',
#  'rheoceros',
#  'robotiq-gripper-interface',
#  'selling-partner-api-docs',
#  'selling-partner-api-models',
#  'selling-partner-api-php-release',
#  'selling-partner-api-postman',
#  'selling-partner-api-samples',
#  'selling-partner-api-sdk',
#  'seqzero',
#  'service-model-swift-code-generate',
#  'sid-provision',
#  'sid-signing-tool',
#  'sketch-constructor',
#  'smoke-aws',
#  'smoke-aws-credentials',
#  'smoke-aws-generate',
#  'smoke-aws-support',
#  'smoke-dynamodb',
#  'smoke-framework',
#  'smoke-framework-application-generate',
#  'smoke-framework-examples',
#  'smoke-http',
#  'sparse-vqvae',
#  'ss-aga-kgc',
#  'sto-transformer',
#  'style-dictionary',
#  'supply-chain-simulation-environment',
#  'tiny-attribution-generator',
#  'traffic-quality-smart-pixel-loader',
#  'trans-encoder',
#  'user-satisfaction-modeling',
#  'workspace-resolver',
#  'ws-vae',
#  'xfer',
#  'zeek-plugin-bacnet',
#  'zeek-plugin-enip',
#  'zeek-plugin-profinet',
#  'zeek-plugin-s7comm',
#  'zeek-plugin-tds',
#  'zero-shot-rlhr']

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool']

# %%
len(repos_name)
# Out:
# 163

# %% [markdown]
# ### Linguagem dos repositórios

# %%
repos_list[1][1]['language']
# Out:
# 'Python'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 163

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'Python',
#  'Java',
#  'C#',
#  'HTML',
#  'Kotlin',
#  None,
#  'TypeScript',
#  'PHP',
#  'PHP',
#  None,
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'TypeScript',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  None,
#  'Mustache',
#  'PHP',
#  None,
#  'Java',
#  'PHP',
#  'Python',
#  'Swift',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'Python',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Python']

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amzn = pd.DataFrame()
dados_amzn['name'] = repos_name
dados_amzn['language'] = repos_language
print(len(repos_language), len(repos_name))
dados_amzn
# Out:
# 163 163
#                                         name          language
# 0                                    .github              None
# 1                    ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-server-side-template            Smarty
# 3                ads-pao-amznjs-gtm-template            Smarty
# 4                                 alexa-coho        JavaScript
# ..                                       ...               ...
# 158                         zeek-plugin-enip              Zeek
# 159                     zeek-plugin-profinet              Zeek
# 160                       zeek-plugin-s7comm              Zeek
# 161                          zeek-plugin-tds              Zeek
# 162                           zero-shot-rlhr            Python
#
# [163 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame em CSV

# %%
dados_amzn.to_csv('meu_path')

# %% [markdown]
# ### Armazenando os dados

# %% [markdown]
# Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

# %%
data = {
    'name': 'meu_repo',
    'description': 'minha_descricao',
    'private': False
}
r = requests.post(url=url, headers=headers, json=data)
r
# Out:
# <Response [422]>

# %% [markdown]
# ### Formato do Arquivo

# %%
import base64

# %%
with open('path', 'rb') as f:
    file_content = f.read()
encoded_content = base64.b64encode(file_content)

# %% [markdown]
# ### Upload de arquivo

# %%
api_base_url = 'https://api.github.com'
username = 'meu_nome'
repo = 'meu_repo'
path = 'meu_path'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/thallystorres/lang-utils/contents/amazon_repos_languages.csv'

# %%
data = {
    'message': 'minha_mensagem',
    'content': encoded_content.decode('utf-8')
}
r = requests.put(url=url, headers=headers, json=data)
r.status_code
# Out:
# 422
